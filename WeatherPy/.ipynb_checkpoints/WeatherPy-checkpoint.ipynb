# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# empty lists
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# call counter 
record = 1

# print the first header
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop 
for city in cities:  
    
    # appends
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase the counte
        record= record + 1
        
        # Wait a second for the next loop
        time.sleep(1.01)
        
    # If no record found "skip" to the next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 | Vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0b173661708166ff355f5ef5861b13ca&q=vaitape
# Processing Record 2 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0b173661708166ff355f5ef5861b13ca&q=cape town
# Processing Record 3 | Nambucca Heads
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0b173661708166ff355f5ef5861b13ca&q=nambucca heads
# Processing Record 4 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0b173661708166ff355f5ef5861b13ca&q=katsuura
# Processing Record 5 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0b173661708166ff355f5ef5861b13ca&q=kapaa
# Processing Record 6 | Chokurdakh
# ...

# %%
# Create the dictionary

weather_dictionary = {
        "City": city_name,
        "Cloudiness":cloudiness, 
        "Country":country,
        "Date":date, 
        "Humidity": humidity,
        "Lat":lat, 
        "Lng":lng, 
        "Max Temp": max_temp,
        "Wind Speed":wind_speed }

# Create the data frame from the dictionary
weather_datafm = pd.DataFrame(weather_dictionary)
weather_datafm.count()
# Out:
# City          564
# Cloudiness    564
# Country       564
# Date          564
# Humidity      564
# Lat           564
# Lng           564
# Max Temp      564
# Wind Speed    564
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Save data frame to CSV
weather_datafm.to_csv('output_data/cities.csv')
weather_datafm.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Vaitape          21      PF  1571800083        68 -16.52 -151.75
# 1       Cape Town          20      ZA  1571800066        71 -33.93   18.42
# 2  Nambucca Heads           2      AU  1571800086        56 -30.64  152.99
# 3        Katsuura          75      JP  1571800087        64  33.93  134.50
# 4           Kapaa          90      US  1571800089        62  22.08 -159.32
#
#    Max Temp  Wind Speed
# 0     80.69        5.12
# 1     57.00        5.82
# 2     82.00       20.80
# 3     75.00        9.17
# 4     84.20        5.82

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# scatter plot
plt.scatter(weather_datafm["Lat"], weather_datafm["Max Temp"], marker="o", s=10)

# labels
plt.title("City Latitude vs. Max Temperature 10/22/19")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save and show the plot!
plt.savefig("Max_Temp_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build the scatter plot
plt.scatter(weather_datafm["Lat"], weather_datafm["Humidity"], marker="o", s=10, c="b")

# labels
plt.title("City Latitude vs. Humidity 10/22/19 ")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure and show the plot
plt.savefig("Humidity_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_datafm["Lat"], weather_datafm["Cloudiness"], marker="o", s=10, c="g")

# labels
plt.title("City Latitude vs. Cloudiness 10/22/19")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure and show the plot
plt.savefig("Cloudiness_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plot
plt.scatter(weather_datafm["Lat"], weather_datafm["Wind Speed"], marker="o", s=10, c="y")

# Labels
plt.title("City Latitude vs. Wind Speed 10/22/19")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure and show the plot
plt.savefig("Wind_Speed_vs_Latitude.png")
plt.show()
